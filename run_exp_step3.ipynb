# %%
run exp_step3.py
# Out:
# Cross validation ...
# prism_iii:   1%|          | 134/13449 [00:00<00:19, 671.32it/s]
# 5-fold Cross validation on training set:
#       AUROC     AUPRC
# 0  0.823260  0.346654
# 1  0.827536  0.345502
# 2  0.829046  0.350677
# 3  0.826733  0.341452
# 4  0.823931  0.345769
# 5-fold Cross validation on test set:
#       AUROC     AUPRC
# 0  0.831320  0.336325
# 1  0.813116  0.343581
# 2  0.810855  0.317970
# 3  0.832523  0.341477
# 4  0.828384  0.345255
# Construct Final Model ...
# ...
